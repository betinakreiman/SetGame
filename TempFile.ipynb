# %%
from MySetClass import *
# %matplotlib inline
# import matplotlib.pyplot as plt
# %matplotlib qt5


deck = createDeck()
table, deck = generateTableBeginning(deck)

scoreP = 0
scoreC = 0 

# %matplotlib inline

showTable(table)
# while len(deck) > 0
# table, scoreP = playersTurn(table, scoreP)
# Out:
# showTable. tableCount =  12
# Row is 0 Column is 0
# Row is 0 Column is 1
# Row is 0 Column is 2
# Row is 1 Column is 0
# Row is 1 Column is 1
# Row is 1 Column is 2
# Row is 2 Column is 0
# Row is 2 Column is 1
# Row is 2 Column is 2
# Row is 3 Column is 0
# Row is 3 Column is 1
# Row is 3 Column is 2

# %%
# %matplotlib inline
# %matplotlib inline
import matplotlib.pyplot as plt

while len(deck) > 0: 
    # %matplotlib inline
    table, scoreP, errM = playersTurn(table, scoreP)
    if errM == 'Problem':
        break
    table, setOrNot, scoreC = computersTurn(table, scoreC)
    # %matplotlib inline
    # fig.canvas.draw()
    if setOrNot == False:
        print('Cards were added to the table.')
        table, deck, errMsg = hitMe(table, deck)
        showTable(table)
    showTable(table)
    print('Length of deck is', len(deck))
    print('Length of table is', len(table))
    print('Player score is', scoreP)
    print('Computer score is', scoreC)
# Out:
# Do you see a set? (yes or no)yes
# Please enter the three cards of your set.1 2 3
# Sos un boru. You lost a point
# Computer found a set.
# Computer score is 1
# showTable. tableCount =  9
# Row is 0 Column is 0
# Row is 0 Column is 1
# Row is 0 Column is 2
# Row is 1 Column is 0
# Row is 1 Column is 1
# Row is 1 Column is 2
# Row is 2 Column is 0
# Row is 2 Column is 1
# Row is 2 Column is 2
# showTable. tableCount =  9
# Row is 0 Column is 0
# Row is 0 Column is 1
# Row is 0 Column is 2
# Row is 1 Column is 0
# Row is 1 Column is 1
# Row is 1 Column is 2
# Row is 2 Column is 0
# Row is 2 Column is 1
# Row is 2 Column is 2
# Length of deck is 69
# Length of table is 9
# Player score is -1
# Computer score is 1
# Do you see a set? (yes or no)no
# Computer score is 1
# Cards were added to the table.
# showTable. tableCount =  12
# Row is 0 Column is 0
# Row is 0 Column is 1
# Row is 0 Column is 2
# Row is 1 Column is 0
# Row is 1 Column is 1
# Row is 1 Column is 2
# Row is 2 Column is 0
# Row is 2 Column is 1
# Row is 2 Column is 2
# Row is 3 Column is 0
# Row is 3 Column is 1
# Row is 3 Column is 2
# showTable. tableCount =  12
# Row is 0 Column is 0
# Row is 0 Column is 1
# Row is 0 Column is 2
# Row is 1 Column is 0
# Row is 1 Column is 1
# Row is 1 Column is 2
# Row is 2 Column is 0
# Row is 2 Column is 1
# Row is 2 Column is 2
# Row is 3 Column is 0
# Row is 3 Column is 1
# Row is 3 Column is 2
# Length of deck is 66
# Length of table is 12
# Player score is -1
# Computer score is 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     883             try:
# --> 884                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     885             except Exception:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     474         """
# --> 475         parts = [self.recv(flags, copy=copy, track=track)]
#     476         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-96f0e0d41a2c> in <module>
#       5 while len(deck) > 0:
#       6     # %matplotlib inline
# ----> 7     table, scoreP, errM = playersTurn(table, scoreP)
#       8     if errM == 'Problem':
#       9         break
#
# ~/Desktop/Life/PythonProjects/SetGame/MySetClass.py in playersTurn(table, scoreP)
#     259     errMsg = 'None'
#     260
# --> 261     userSetOrNot = input("Do you see a set? (yes or no)")
#     262     if userSetOrNot == "no" or userSetOrNot == "n":
#     263         return table, scoreP, errMsg
#
# ~/opt/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     857             self._parent_ident,
#     858             self._parent_header,
# --> 859             password=False,
#     860         )
#     861
#
# ~/opt/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     887             except KeyboardInterrupt:
#     888                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 889                 raise KeyboardInterrupt
#     890             else:
#     891                 break
#
# KeyboardInterrupt:

# %%
while setInTable(table) == True:
    showTable(table)
    table, scoreP, errM = playersTurn(table, scoreP)
    if errM == 'Problem':
        break
    table, setOrNot, scoreC = computersTurn(table, scoreC)
# Out:
# showTable. tableCount =  12
# Row is 0 Column is 0
# Row is 0 Column is 1
# Row is 0 Column is 2
# Row is 1 Column is 0
# Row is 1 Column is 1
# Row is 1 Column is 2
# Row is 2 Column is 0
# Row is 2 Column is 1
# Row is 2 Column is 2
# Row is 3 Column is 0
# Row is 3 Column is 1
# Row is 3 Column is 2
# Do you see a set? (yes or no)yes
# Please enter the three cards of your set.1 2 3
# Sos un boru. You lost a point
# Computer found a set.
# Computer score is 2
# showTable. tableCount =  9
# Row is 0 Column is 0
# Row is 0 Column is 1
# Row is 0 Column is 2
# Row is 1 Column is 0
# Row is 1 Column is 1
# Row is 1 Column is 2
# Row is 2 Column is 0
# Row is 2 Column is 1
# Row is 2 Column is 2

# %%
print('End of game.')
if scoreP > scoreC:
    print('Good job! You won!')
else:
    print('Good try! You should keep practicing.')
print('Player score is', scoreP)
print('Computer score is', scoreC)
# Out:
# End of game.
# Good try! You should keep practicing.
# Player score is -2
# Computer score is 2
